# %%
import requests
from bs4 import BeautifulSoup

url = 'http://review-movie2021.herokuapp.com/'
html= requests.get(url)
soup= BeautifulSoup(html.text,'lxml')

titles=soup.find_all('h2')
for title in titles:
    print(title.get_text())
movie_urls=soup.find_all('img',class_='alignleft')
for movie_url in movie_urls:
    print(movie_url.get('src'))
# Out:
# ケージ・ダイブ
#
# フェリシーと夢のトウシューズ
#
# 海底47m
#
# ハイドリヒを撃て！「ナチの野獣」暗殺作戦
#
# RE:BORN リボーン
#
# 海の彼方
#
# コスタリカの奇跡　積極的平和国家のつくり方
#
# チャルカ　未来を紡ぐ糸車
#
# デス・レース2000年
#
# 隣人のゆくえ　あの夏の歌声
#
# スパイダーマン　ホームカミング
#
# 少女ファニーと運命の旅
#
# 劇場版　仮面ライダーエグゼイド　トゥルー・エンディング
#
# エブリシング
#
# 夜明けの祈り
#
# ロスト・イン・パリ
#
# スターシップ9
#
# きっと、いい日が待っている
#
# 俺たちポップスター
#
# 宇宙戦隊キュウレンジャー THE MOVIE ゲース・インダベーの逆襲
#
# http://eiga.k-img.com/images/movie/87277/photo/7676faf8d6b674fc/160.jpg?1496800436
# http://eiga.k-img.com/images/movie/86684/photo/32bcf36ea48fdfe5/160.jpg?1496105975
# http://eiga.k-img.com/images/movie/86190/photo/a73fd07f397ab3b4/160.jpg?1482223763
# http://eiga.k-img.com/images/movie/86851/photo/fa701169cd431c9d/160.jpg?1492477774
# http://eiga.k-img.com/images/movie/87343/photo/2806ea15601b58f4/160.jpg?1498007612
# http://eiga.k-img.com/images/movie/86782/photo/420e627800c31c6d/160.jpg?1496994986
# http://eiga.k-img.com/images/movie/87025/photo/6201fdbc7fa8644c/160.jpg?1499824666
# http://eiga.k-img.com/images/movie/87378/photo/2e475c1288076515/160.jpg?1499050427
# http://eiga.k-img.com/images/movie/46975/photo/ae48ed870a87969c/160.jpg?1495764865
# http://eiga.k-img.com/images/movie/87223/photo/4c8e0f5aed8a7545/160.jpg?1499048888
# http://eiga.k-img.com/images/movie/82383/photo/a1ef6ae2ef8c9570/160.jpg?1496907883
# http://eiga.k-img.com/images/movie/86923/photo/983b9e199ae963f2/160.jpg?1497336954
# http://eiga.k-img.com/images/movie/86299/photo/b16f3cce915682f0/160.jpg?1500963284
# http://eiga.k-img.com/images/movie/87147/photo/fcc6341f0782ef1f/160.jpg?1500344010
# http://eiga.k-img.com/images/movie/86006/photo/f432db2674bc8366/160.jpg?1496395212
# http://eiga.k-img.com/images/movie/87049/photo/f78706835e2097e1/160.jpg?1493688761
# http://eiga.k-img.com/images/movie/87139/photo/ef8a0997e3213c8f/160.jpg?1496625299
# http://eiga.k-img.com/images/movie/87029/photo/336e6e94b7361301/160.jpg?1498006859
# http://eiga.k-img.com/images/movie/85070/photo/df3de95f0a8ad624/160.jpg?1496366031
# http://eiga.k-img.com/images/movie/86300/photo/6a7b030a7d0ef4a5/160.jpg?1500963747

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://review-movie2021.herokuapp.com/'
html= requests.get(url)
soup= BeautifulSoup(html.text,'lxml')

titles=soup.find_all('h2')
for title in titles:
    print(title.get_text())
    
img_url='http://review-movie2021.herokuapp.com/products/342'
img_html=requests.get(img_url)
imgs=BeautifulSoup(img_html.text,'lxml')

movie_url=imgs.find('img',class_='alignleft')
# for movie_url in movie_urls:
print(movie_url.get('src'))
# Out:
# ケージ・ダイブ
#
# フェリシーと夢のトウシューズ
#
# 海底47m
#
# ハイドリヒを撃て！「ナチの野獣」暗殺作戦
#
# RE:BORN リボーン
#
# 海の彼方
#
# コスタリカの奇跡　積極的平和国家のつくり方
#
# チャルカ　未来を紡ぐ糸車
#
# デス・レース2000年
#
# 隣人のゆくえ　あの夏の歌声
#
# スパイダーマン　ホームカミング
#
# 少女ファニーと運命の旅
#
# 劇場版　仮面ライダーエグゼイド　トゥルー・エンディング
#
# エブリシング
#
# 夜明けの祈り
#
# ロスト・イン・パリ
#
# スターシップ9
#
# きっと、いい日が待っている
#
# 俺たちポップスター
#
# 宇宙戦隊キュウレンジャー THE MOVIE ゲース・インダベーの逆襲
#
# http://eiga.k-img.com/images/movie/87277/photo/41d5d29a7ea46b41/320.jpg?1499062696

# %%
import requests
from bs4 import BeautifulSoup

# プログラムで使用できるようにUrlを読み込む
url = 'http://review-movie2021.herokuapp.com/'
html= requests.get(url)
soup= BeautifulSoup(html.text,'lxml')

titles=soup.find_all('h2')
img_paths=[]

# タイトルを表示させ、画像のUrlをaタグのhrefから読み取り、それをimg_pathsへと格納していく
for title in titles:
    print(title.get_text())
    for a in title.find_all('a'):
        img_paths.append(a.get('href'))

for img_path in img_paths:
    # 個別のurlのパスを足して作成
    img_url = url+img_path
    img_html = requests.get(img_url)
    # プログラムで使えるように設定
    imgs = BeautifulSoup(img_html.text,'lxml')
    movie_url = imgs.find('img',class_= 'alignleft')
    print(movie_url.get('src'))
# Out:
# ケージ・ダイブ
#
# フェリシーと夢のトウシューズ
#
# 海底47m
#
# ハイドリヒを撃て！「ナチの野獣」暗殺作戦
#
# RE:BORN リボーン
#
# 海の彼方
#
# コスタリカの奇跡　積極的平和国家のつくり方
#
# チャルカ　未来を紡ぐ糸車
#
# デス・レース2000年
#
# 隣人のゆくえ　あの夏の歌声
#
# スパイダーマン　ホームカミング
#
# 少女ファニーと運命の旅
#
# 劇場版　仮面ライダーエグゼイド　トゥルー・エンディング
#
# エブリシング
#
# 夜明けの祈り
#
# ロスト・イン・パリ
#
# スターシップ9
#
# きっと、いい日が待っている
#
# 俺たちポップスター
#
# 宇宙戦隊キュウレンジャー THE MOVIE ゲース・インダベーの逆襲
#
# http://eiga.k-img.com/images/movie/87277/photo/41d5d29a7ea46b41/320.jpg?1499062696
# http://eiga.k-img.com/images/movie/86684/photo/e488779e0ed18eb9/320.jpg?1499740950
# http://eiga.k-img.com/images/movie/86190/photo/aa98ce6f5526600d/320.jpg?1496300656
# http://eiga.k-img.com/images/movie/86851/photo/85704cea7bd6f6b2/320.jpg?1491358304
# http://eiga.k-img.com/images/movie/87343/photo/614e1e14b2217216/320.jpg?1498007655
# http://eiga.k-img.com/images/movie/86782/photo/eb83471baa036e3b/320.jpg?1496995253
# http://eiga.k-img.com/images/movie/87025/photo/0c7d3ffb139fe195/320.jpg?1499825157
# http://eiga.k-img.com/images/movie/87378/photo/c670dc0f6cc0133f/320.jpg?1499050431
# http://eiga.k-img.com/images/movie/46975/photo/a128b80c7c15da37/320.jpg?1497924016
# http://eiga.k-img.com/images/movie/87223/photo/29fda6b687d32992/320.jpg?1496709969
# http://eiga.k-img.com/images/movie/82383/photo/0b817fb31d09c8f8/320.jpg?1495614441
# http://eiga.k-img.com/images/movie/86923/photo/0594040d871cb912/320.jpg?1495070724
# http://eiga.k-img.com/images/movie/86299/photo/908fd8dbfaddae44/320.jpg?1499915987
# http://eiga.k-img.com/images/movie/87147/photo/01cd83f50b35f592/320.jpg?1499651801
# http://eiga.k-img.com/images/movie/86006/photo/21db1e76444cdf3f/320.jpg?1496395345
# http://eiga.k-img.com/images/movie/87049/photo/f644c3ae5d95b99e/320.jpg?1493688809
# http://eiga.k-img.com/images/movie/87139/photo/0be455862433630b/320.jpg?1495158426
# http://eiga.k-img.com/images/movie/87029/photo/e2b0dc1639406da5/320.jpg?1498018016
# http://eiga.k-img.com/images/movie/85070/photo/3acc00d40ba746fb/320.jpg?1498702556
# http://eiga.k-img.com/images/movie/86300/photo/ea8e50fac82eb91c/320.jpg?1499916101

# %%
import csv
import requests
import time
from bs4 import BeautifulSoup

# 最初の処理と、共通の処理を定義しておく
next_url=''
top_url = 'http://review-movie2021.herokuapp.com/'
movie_titles=[]
movie_images=[]

while True:
    # プログラム適用処理
    url=top_url+next_url
    html=requests.get(url)
    soup=BeautifulSoup(html.text,'lxml')
    
    # nextの要素があれば、処理を行う。（最後のページ以外）
    next_link=soup.find('span',class_='next')
    if next_link != None:
        # next要素のhrefを取り出し、リンクを代入しておく
        next_url_tag=next_link.find('a')
        next_url = next_url_tag.get('href')
        
        titles = soup.find_all('h2')
        img_urls = []
         # タイトルを配列に追加し、、画像のUrlをaタグのhrefから読み取り、それをimg_urlsへと格納していく
        for title in titles:
            movie_title=title.get_text()
            movie_title=movie_title.replace('\u3000','') 
            movie_titles.append(movie_title.strip('\n'))
            for a in title.find_all('a'):
                img_urls.append(a.get('href'))
        # 画像を配列に追加していく
        for img_url in img_urls:
            # 先ほど読み取った画像のhref要素とホーム画面のurlを組み合わせて作品別のurlを作成。それをプログラムできるようにする
            img_link = top_url+img_url
            img_html = requests.get(img_link)
            imgs = BeautifulSoup(img_html.text,'lxml')
            # 作品別の紹介ページから、img要素を、そしてhrefを指定してmovie_imagesへ格納していく
            movie_url = imgs.find('img',class_= 'alignleft')
            movie_images.append(movie_url.get('src'))
        # ページ遷移の際に２秒間休憩。サーバーの負荷を減らすため                        
        time.sleep(1)                
    else:
        break
print(movie_titles)
print(movie_images)
