# %% [markdown]
# PCAを用いた主成分分析

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
mnist = datasets.load_digits()

# %%
print(mnist.data.shape)
# Out:
# (1797, 64)

# %%
print(mnist.target.shape)
# Out:
# (1797,)

# %%
x_compressed = PCA(n_components = 2).fit_transform(mnist.data)

# %%
print(x_compressed.shape)
# Out:
# (1797, 2)

# %%
plt.scatter(x_compressed[:,0],x_compressed[:,1],c = mnist.target)
plt.colorbar()

# %% [markdown]
# tーSNA

# %%
from sklearn.manifold import TSNE
mnist= datasets.load_digits()

# %%
print(mnist.data.shape)
# Out:
# (1797, 64)

# %%
print(mnist.target.shape)
# Out:
# (1797,)

# %%
x_compressed = TSNE(n_components = 2,random_state = 0).fit_transform(mnist.data)
print(x_compressed.shape)
# Out:
# /Users/odanaoki/.anyenv/envs/pyenv/versions/3.10.2/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/odanaoki/.anyenv/envs/pyenv/versions/3.10.2/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (1797, 2)

# %%
plt.scatter(x_compressed[:,0],x_compressed[:,1],c = mnist.target)
plt.colorbar()
